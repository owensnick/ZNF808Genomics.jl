# %%
import regex as re

C2H2_regex = re.compile("C.{2,4}C.{5}(.)..(.).{2}(.)H.{3,5}H")

# %%
#Ensembl ENST00000359798.9

human_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(human_ZNF808)])
# Out:
# 'HYC-YSC-QAI-QHR-CYN-HSR-QTR-CQR-RSC-HSY-RVV-QHR-QAS-WQR-YSW-CYK-NSC-QTC-HSY-RYR-EHR-RHR-DTH'

# %%
#Ensembl ENSPPAT00000053018.1

bonobo_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(bonobo_ZNF808)])
# Out:
# 'HYC-YSC-QAI-QHR-CYN-HSR-QTR-CQR-RSC-HSY-RVV-QHR-QAS-WQR-YSW-CYK-HSC-QTC-HSY-RYR-EHR-RHR-DTH'

# %%
#Ensembl ENSGGOT00000023201.2

gorilla_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(gorilla_ZNF808)])
# Out:
# 'HYC-YSC-QAI-QHR-CYN-HSR-QTR-CQR-CSC-HSY-RVV-QHR-QAS-WQR-YSW-CYK-NSC-QTC-HSY-RYR-EHR-RHR-DTH'

# %%
#Ensembl ENSPPYT00000033844.2

orang_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(orang_ZNF808)])
# Out:
# 'HYC-YSC-QAI-QHR-CYN-HSR-QTR-CQR-RSC-HSY-RVV-QHR-QAS-WQR-YSW-CYK-NSC-QSC-HSY-RYR-EHR-RHR-DTH'

# %%
#Ensembl ENSNLET00000007672.2

gibbon_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(gibbon_ZNF808)])
# Out:
# 'HYC-QSC-QAV-QHR-CYN-HSR-QTR-CQR-RSC-HSY-RVV-QHR-QAS-WQR-YSW-CYK-NSC-QTC-HSY-RYR-EHR-RHR-DTH'

# %%
#NCBI XM_030942019.1

golden_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(golden_ZNF808)])
# Out:
# 'HYC-QSC-QAI-QHR-CYN-QNR-QTI-CQR-HYC-HYC-HSC-RSC-RVI-QHR-RTT-WQR-HSC-CYK-HSC-QSC-HSC-RLR-RHS-RHR-EMH'

# %%
#Ensembl ENSCSAT00000016554.1

chloro_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(chloro_ZNF808)])
# Out:
# 'QAI-QHR-CYN-QNR-QTI-CQR-HYC-HYC-HSC-RSC-RVI-QHR-RTT-WQR-HSC-CYK-HSC-QSC-HSC-RLR-RHS-RHR-EMH'

# %%
#Ensembl ENSCATT00000051327.1

mangabey_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(mangabey_ZNF808)])
# Out:
# 'HAI-QHR-CYN-QNR-QTI-CQR-HYC-HYC-HSC-RSC-RVI-QHR-RTT-WQR-HSC-CYK-HSC-QSC-HSC-RLR-RHS-RHR-EVH'

# %%
#Ensembl ENSMMUT00000086369.1

macaque_ZNF808 = "..."
"-".join(["".join(x) for x in C2H2_regex.findall(macaque_ZNF808)])
# Out:
# 'HAI-QHR-CYN-QNR-QTI-CQR-HYC-HYC-HSC-RSC-RVI-QHR-RTT-WQR-HSC-CYK-HSC-QSC-HSC-RLR-RHS-RHR-EVH'
